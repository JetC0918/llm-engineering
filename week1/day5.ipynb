# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %%
print(ed.get_contents())
# Out:
# Webpage Title:
# Home - Edward Donner
# Webpage Contents:
# Home
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Well, hi there.
# I’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy DJing (but I’m badly out of practice), amateur electronic music production (
# very
# amateur) and losing myself in
# Hacker News
# , nodding my head sagely to things I only half understand.
# I’m the co-founder and CTO of
# Nebula.io
# . We’re applying AI to a field where it can make a massive, positive impact: helping people discover their potential and pursue their reason for being. Recruiters use our product today to source, understand, engage and manage talent. I’m previously the founder and CEO of AI startup untapt,
# acquired in 2021
# .
# We work with groundbreaking, proprietary LLMs verticalized for talent, we’ve
# patented
# our matching model, and our award-winning platform has happy customers and tons of press coverage.
# Connect
# with me for more!
# May 28, 2025
# Connecting my courses – become an LLM expert and leader
# May 18, 2025
# 2025 AI Executive Briefing
# April 21, 2025
# The Complete Agentic AI Engineering Course
# January 23, 2025
# LLM Workshop – Hands-on with Agents – resources
# Navigation
# Home
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Get in touch
# ed [at] edwarddonner [dot] com
# www.edwarddonner.com
# Follow me
# LinkedIn
# Twitter
# Facebook
# Subscribe to newsletter
# Type your email…
# Subscribe

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/black-forest-labs/FLUX.1-Kontext-dev',
#  '/tencent/Hunyuan-A13B-Instruct',
#  '/google/gemma-3n-E4B-it',
#  '/THUDM/GLM-4.1V-9B-Thinking',
#  '/kyutai/tts-1.6b-en_fr',
#  '/models',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/black-forest-labs/FLUX.1-Kontext-Dev',
#  '/spaces/ilcve21/Sparc3D',
#  '/spaces/AIDC-AI/Ovis-U1-3B',
#  '/spaces/tencent/Hunyuan3D-2.1',
#  '/spaces',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets/HuggingFaceFW/fineweb-2',
#  '/datasets/facebook/seamless-interaction',
#  '/datasets/FreedomIntelligence/ShareGPT-4o-Image',
#  '/datasets/black-forest-labs/kontext-bench',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/changelog',
#  'https://endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/about'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'company page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'community page', 'url': 'https://huggingface.co/discuss'},
#   {'type': 'GitHub page', 'url': 'https://github.com/huggingface'},
#   {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'},
#   {'type': 'LinkedIn page',
#    'url': 'https://www.linkedin.com/company/huggingface/'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'docs page', 'url': 'https://huggingface.co/docs'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# black-forest-labs/FLUX.1-Kontext-dev
# Updated
# 8 days ago
# •
# 155k
# •
# 1.32k
# tencent/Hunyuan-A13B-Instruct
# Updated
# 3 days ago
# •
# 13.7k
# •
# 709
# google/gemma-3n-E4B-it
# Updated
# 2 days ago
# •
# 197k
# •
# 445
# THUDM/GLM-4.1V-9B-Thinking
# Updated
# 2 days ago
# •
# 7.03k
# •
# 204
# kyutai/tts-1.6b-en_fr
# Updated
# 2 days ago
# •
# 7.19k
# •
# 164
# Browse 1M+ models
# Spaces
# Running
# 9.25k
# 9.25k
# DeepSite v2
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# MCP
# 555
# 555
# FLUX.1 Kontext
# ⚡
# Kontext image editing on FLUX[dev]
# Running
# 1.04k
# 1.04k
# Sparc3D
# 🏃
# Next-Gen High-Resolution 3D Model Generation
# Running
# on
# Zero
# 124
# 124
# Ovis U1 3B
# 🎨
# Demo for multimodal understanding and generation
# Running
# on
# Zero
# 622
# 622
# Hunyuan3D-2.1
# 👻
# Image-to-3D Generation
# Browse 400k+ applications
# Datasets
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 22.9k
# •
# 8.15k
# HuggingFaceFW/fineweb-2
# Updated
# 8 days ago
# •
# 38.3k
# •
# 561
# facebook/seamless-interaction
# Updated
# 8 days ago
# •
# 1
# •
# 80
# FreedomIntelligence/ShareGPT-4o-Image
# Updated
# 4 days ago
# •
# 75
# •
# 68
# black-forest-labs/kontext-bench
# Updated
# 9 days ago
# •
# 34
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Team & Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 766 models
# •
# 3.52k followers
# AI at Meta
# Enterprise
# company
# •
# 2.17k models
# •
# 6.7k followers
# Amazon
# company
# •
# 20 models
# •
# 3.27k followers
# Google
# Enterprise
# company
# •
# 1.01k models
# •
# 18.7k followers
# Intel
# company
# •
# 207 models
# •
# 2.7k followers
# Microsoft
# company
# •
# 396 models
# •
# 13.3k followers
# Grammarly
# Team
# company
# •
# 10 models
# •
# 166 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 309 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 146,474
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 29,647
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,340
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,735
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,868
# Fast tokenizers optimized for research & production
# TRL
# 14,454
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,986
# State-of-the-art ML running directly in your browser
# smolagents
# 20,925
# Smol library to build great agents in Python
# PEFT
# 18,942
# Parameter-efficient finetuning for large language models
# Datasets
# 20,338
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,290
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,900
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 47,002
# AI & ML interests
# The AI community building the future.
# Recent Activity
# fracapuano
# updated
# a dataset
# about 22 hours ago
# huggingface/documentation-images
# dylanebert
# authored
# a paper
# 11 days ago
# 3D Arena: An Open Platform for Generative 3D Evaluation
# loubnabnl
# authored
# a paper
# 28 days ago
# The Common Pile v0.1: An 8TB Dataset of Public Domain and Openly
#   Licensed Text
# View all activity
# Articles
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 46
# Team members
# 213
# +179
# +166
# +145
# +135
# +115
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 211k
# •
# •
# 51
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 8.24M
# •
# •
# 718
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 1.06M
# •
# 198
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# 0.1B
# •
# Updated
# Dec 19, 2023
# •
# 3.5M
# •
# •
# 787
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 211k
# •
# •
# 51
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 8.24M
# •
# •
# 718
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 1.06M
# •
# 198
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# 0.1B
# •
# Updated
# Dec 19, 2023
# •
# 3.5M
# •
# •
# 787
# spaces
# 29
# Sort:
# 		Recently updated
# pinned
# Running
# 14
# Enterprise Hub
# 🔒
# Why you need it, how to get it
# huggingface
# 8 days ago
# pinned
# Running
# on
# CPU Upgrade
# 12
# Hugging Face Fast
# 🏎
# Test Hugging Face bandwidth
# huggingface
# 23 days ago
# pinned
# Running
# 94
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# 184
# Inference Playground
# 🔋
# Toggle dark/light theme on Hugging Face Playground
# huggingface
# 17 days ago
# Running
# on
# CPU Upgrade
# 13
# Openapi
# 🦀
# Hub API Documentation
# huggingface
# 17 days ago
# Running
# 438
# AI Deadlines
# ⚡
# Organize project deadlines with AI assistance
# huggingface
# 27 days ago
# View 29
# 							Spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/time-series-transformer-tourism-monthly
# Time Series Forecasting
# •
# 0.0B
# •
# Updated
# May 24
# •
# 4.28k
# •
# 22
# huggingface/timesfm-tourism-monthly
# 0.0B
# •
# Updated
# Mar 31
# •
# 17
# •
# 2
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 2.17k
# •
# •
# 62
# huggingface/falcon-40b-gptq
# Text Generation
# •
# 7B
# •
# Updated
# Jun 14, 2023
# •
# 34
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 29.3k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# 0.1B
# •
# Updated
# Mar 22, 2023
# •
# 239
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 29.1k
# •
# 6
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 13
# •
# 5
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 83.2k
# •
# •
# 81
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# View 16
# 							models
# datasets
# 34
# Sort:
# 		Recently updated
# huggingface/documentation-images
# Viewer
# •
# Updated
# about 22 hours ago
# •
# 52
# •
# 3M
# •
# 72
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# 8 days ago
# •
# 1.73k
# •
# 2.14k
# •
# 26
# huggingface/cats-image
# Viewer
# •
# Updated
# 15 days ago
# •
# 1
# •
# 9.88k
# •
# 2
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# 21 days ago
# •
# 70
# •
# 544
# •
# 7
# huggingface/label-files
# Updated
# 23 days ago
# •
# 2.09k
# •
# 18
# huggingface/policy-docs
# Viewer
# •
# Updated
# Jun 3
# •
# 24
# •
# 2.31k
# •
# 12
# huggingface/electricity-production
# Viewer
# •
# Updated
# May 22
# •
# 397
# •
# 124
# •
# 1
# huggingface/badges
# Viewer
# •
# Updated
# Apr 8
# •
# 1
# •
# 1.39M
# •
# 45
# huggingface/gemini-results-new-cs-papers-2025-02-11-100-230-updated
# Viewer
# •
# Updated
# Feb 17
# •
# 130
# •
# 252
# huggingface/wiki_dpr
# Updated
# Feb 5
# •
# 335
# View 34
# 							datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# docs page
# Webpage Title:
# Hugging Face - Documentation
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Documentation
# Hub & Client Libraries
# Hub
# Host Git-based models, datasets, and Spaces on the HF Hub
# Hub Python Library
# Python client to interact with the Hugging Face Hub
# Huggingface.js
# JavaScript libraries for Hugging Face with built-in TS types
# Tasks
# Explore demos, models, and datasets for any ML tasks
# Dataset viewer
# API for metadata, stats, and content of HF Hub datasets
# Deployment & Inference
# Inference Providers
# Call 200k+ models hosted by our 10+ Inference partners
# Inference Endpoints (dedicated)
# Deploy models on dedicated & fully managed infrastructure on HF
# Deploying on AWS
# Train/deploy models from Hugging Face to AWS with DLCs
# Text Generation Inference
# Serve language models with TGI optimized toolkit
# Text Embeddings Inference
# Serve embeddings models with TEI optimized toolkit
# Microsoft Azure
# Deploy Hugging Face models on Microsoft Azure
# Core ML Libraries
# Transformers
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# State-of-the-art Diffusion models in PyTorch
# Datasets
# Access & share datasets for any ML tasks
# Transformers.js
# State-of-the-art ML running directly in your browser
# Tokenizers
# Fast tokenizers optimized for research & production
# Evaluate
# Evaluate and compare models performance
# timm
# State-of-the-art vision models: layers, optimizers, and utilities
# Sentence Transformers
# Embeddings, Retrieval, and Reranking
# Training & Optimization
# PEFT
# Parameter-efficient finetuning for large language models
# Accelerate
# Train PyTorch models with multi-GPU, TPU, mixed precision
# Optimum
# Optimize HF Transformers for faster training/inference
# AWS Trainium & Inferentia
# Train/deploy Transformers/Diffusers on AWS
# TRL
# Train transformers LMs with reinforcement learning
# Safetensors
# Safe way to store/distribute neural network weights
# Bitsandbytes
# Optimize and quantize models with bitsandbytes
# Lighteval
# All-in-one toolkit to evaluate LLMs across multiple backends
# Collaboration & Extras
# Gradio
# Build ML demos and web apps with a few lines of Python
# smolagents
# Smol library to build great agents in Python
# LeRobot
# Making AI for Robotics more accessible with end-to-end learning
# AutoTrain
# AutoTrain API and UI for seamless model training
# Chat UI
# Open source chat frontend powering HuggingChat
# Leaderboards
# Create custom Leaderboards on Hugging Face
# Argilla
# Collaboration tool for building high-quality datasets
# Distilabel
# Framework for synthetic data generation and AI feedback
# Community
# Blog
# Learn
# Discord
# Forum
# Github
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# Inference Providers
# Training and Finetuning Sparse Embedding Models with Sentence Transformers v5
# By
# tomaarsen
# July 1, 2025
# •
# 74
# Community Articles
# view all
# Bringing Fusion Down to Earth: ML for Stellarator Optimization
# By
# cgeorgiaw
# •
# 3 days ago
# •
# 55
# Teaching Data Literacy with Hugging Face's AI Sheets
# By
# ParulPandey
# •
# 5 days ago
# •
# 23
# Common Pitfalls in Sharing Open Source Models on Hugging Face (and How to Dodge Them)
# By
# FriendliAI
# and 2 others
# •
# 4 days ago
# •
# 21
# Understanding Gemma 3n: How MatFormer Gives You Many Models in One
# By
# rishiraj
# •
# 9 days ago
# •
# 20
# Welcome the NVIDIA Llama Nemotron Nano VLM to Hugging Face Hub
# By
# nvidia
# and 10 others
# •
# 8 days ago
# •
# 23
# Automated Discovery of High-Performance GPU Kernels with OpenEvolve
# By
# codelion
# •
# 7 days ago
# •
# 16
# Why We Built the OpenMDW License: A Comprehensive License for ML Models
# By
# linuxfoundation
# •
# 3 days ago
# •
# 10
# IFAD AI Benchmark (Garden V1)
# By
# ifadaiml
# and 8 others
# •
# 5 days ago
# •
# 9
# Should We Still Pretrain Encoders with Masked Language Modeling?
# By
# Nicolas-BZRD
# and 3 others
# •
# 3 days ago
# •
# 9
# How Much Power does a SOTA Open Video Model Use? ⚡🎥
# By
# jdelavande
# and 2 others
# •
# 3 days ago
# •
# 8
# LLMs recognise bias but also reproduce harmful stereotypes: an analysis of bias in leading LLMs
# By
# davidberenstein1957
# and 3 others
# •
# 3 days ago
# •
# 7
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 303
# ⚡ nano-vLLM: Lightweight, Low-Latency LLM Inference from Scratch
# By
# zamal
# •
# 7 days ago
# •
# 6
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 621
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 270
# Fine-tune Llama 3.1 Ultra-Efficiently with Unsloth
# By
# mlabonne
# •
# Jul 29, 2024
# •
# 347
# Mastering Tensor Dimensions in Transformers
# By
# not-lain
# •
# Jan 12
# •
# 77
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 174
# 🤔👀🎬🖥️📖 Kimi-VL-A3B-Thinking-2506: A Quick Navigation
# By
# moonshotai
# and 1 other
# •
# 14 days ago
# •
# 55
# Use hallucination as feature for vibe coding
# By
# chansung
# •
# 5 days ago
# •
# 4
# Gemma 3n fully available in the open-source ecosystem!
# By
# ariG23498
# June 26, 2025
# •
# 99
# Transformers backend integration in SGLang
# By
# marcsun13
# June 23, 2025
# •
# 41
# (LoRA) Fine-Tuning FLUX.1-dev on Consumer Hardware
# By
# derekl35
# June 19, 2025
# •
# 70
# Groq on Hugging Face Inference Providers 🔥
# By
# sbrandeis
# June 16, 2025
# •
# 36
# Enhance Your Models in 5 Minutes with the Hugging Face Kernel Hub
# By
# drbh
# June 12, 2025
# •
# 105
# Featherless AI on Hugging Face Inference Providers 🔥
# By
# sbrandeis
# June 12, 2025
# •
# 43
# Introducing Training Cluster as a Service - a new collaboration with NVIDIA
# By
# jeffboudier
# June 11, 2025
# •
# 23
# ScreenSuite - The most comprehensive evaluation suite for GUI Agents!
# By
# a-mahla
# June 6, 2025
# •
# 49
# KV Cache from scratch in nanoVLM
# By
# ariG23498
# June 4, 2025
# •
# 81
# SmolVLA: Efficient Vision-Language-Action Model trained on Lerobot Community Data
# By
# danaaubakirova
# June 3, 2025
# •
# 175
# No GPU left behind: Unlocking Efficiency with Co-located vLLM in TRL
# By
# toslali-ibm
# June 3, 2025
# guest
# •
# 63
# CodeAgents + Structure: A Better Way to Execute Actions
# By
# akseljoonas
# May 28, 2025
# •
# 63
# 🐯 Liger GRPO meets TRL
# By
# shisahni
# May 25, 2025
# guest
# •
# 44
# Dell Enterprise Hub is all you need to build AI on premises
# By
# jeffboudier
# May 23, 2025
# •
# 19
# Previous
# 1
# 2
# 3
# ...
# 43
# Next
# Community Articles
# Sort:
# 		Trending
# Bringing Fusion Down to Earth: ML for Stellarator Optimization
# By
# cgeorgiaw
# •
# 3 days ago
# •
# 55
# Teaching Data Literacy with Hugging Face's AI Sheets
# By
# ParulPandey
# •
# 5 days ago
# •
# 23
# Common Pitfalls in Sharing Open Source Models on Hugging Face (and How to Dodge Them)
# By
# FriendliAI
# and 2 others
# •
# 4 days ago
# •
# 21
# Understanding Gemma 3n: How MatFormer Gives You Many Models in One
# By
# rishiraj
# •
# 9 days ago
# •
# 20
# Welcome the NVIDIA Llama Nemotron Nano VLM to Hugging Face Hub
# By
# nvidia
# and 10 others
# •
# 8 days ago
# •
# 23
# Automated Discovery of High-Performance GPU Kernels with OpenEvolve
# By
# codelion
# •
# 7 days ago
# •
# 16
# Why We Built the OpenMDW License: A Comprehensive License for ML Models
# By
# linuxfoundation
# •
# 3 days ago
# •
# 10
# IFAD AI Benchmark (Garden V1)
# By
# ifadaiml
# and 8 others
# •
# 5 days ago
# •
# 9
# Should We Still Pretrain Encoders with Masked Language Modeling?
# By
# Nicolas-BZRD
# and 3 others
# •
# 3 days ago
# •
# 9
# How Much Power does a SOTA Open Video Model Use? ⚡🎥
# By
# jdelavande
# and 2 others
# •
# 3 days ago
# •
# 8
# LLMs recognise bias but also reproduce harmful stereotypes: an analysis of bias in leading LLMs
# By
# davidberenstein1957
# and 3 others
# •
# 3 days ago
# •
# 7
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 303
# ⚡ nano-vLLM: Lightweight, Low-Latency LLM Inference from Scratch
# By
# zamal
# •
# 7 days ago
# •
# 6
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 621
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 270
# Fine-tune Llama 3.1 Ultra-Efficiently with Unsloth
# By
# mlabonne
# •
# Jul 29, 2024
# •
# 347
# Mastering Tensor Dimensions in Transformers
# By
# not-lain
# •
# Jan 12
# •
# 77
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 174
# 🤔👀🎬🖥️📖 Kimi-VL-A3B-Thinking-2506: A Quick Navigation
# By
# moonshotai
# and 1 other
# •
# 14 days ago
# •
# 55
# Use hallucination as feature for vibe coding
# By
# chansung
# •
# 5 days ago
# •
# 4
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# company page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# Discover all 568 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We‚Äôre on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# reposted this
# Gradio
# 66,584 followers
# 1d
# Edited
# Report this post
# üèÜ
# SambaNova Systems
# Choice Award Winner!
#
# Caption Creator Pro wins $500 in cash prize!
#
# üì∏ AI-powered Instagram caption generator
# ‚ö° 2s generation with Llama-4-Maverick
# üåç Multi-language support
# üéØ 64 style combinations
#
# Built with @SambaNovaAI's latest models!
# Try Caption Creator PRO here:
# https://lnkd.in/gig8iQ2s
# 47
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Jo√£o Gante
# ML (generation) @ Hugging Face ü§ó
# 1d
# Report this post
# LET'S GO! Cursor using local ü§ó transformers models! You can now test ANY transformers-compatible LLM against your codebase.
#
# From hacking to production, it takes only a few minutes: anything `transformers` does, you can serve into your app üî•
#
# We've iterated on our local `transformers serve`, a server with `transformers` backend, and it now supports more advanced requests -- including the requests from Cursor.
#
# Testing new models, quantization methods, KV caches, decoding methods, (...) should be much easier now ü´∂
#
# Here's a demo with Qwen3 4B:
# (instructions to replicate in a comment)
# ‚Ä¶more
# 432
# 13 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Lysandre Debut
# COSO - Chief Open Source Officer at Hugging Face
# 2d
# Report this post
# A nice walkthrough through the recent OpenMDW license by the
# The Linux Foundation
# , a license dedicated to ML models:
# 50
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Pablo Montalvo
# Machine Learning Engineer @ ü§ó
# 2d
# Report this post
# ùêïùêãùêåùê¨ ùêßùêûùêûùêù ùê≠ùê® ùêõùêû ùêÆùêßùêõùê•ùê®ùêöùê≠ùêûùêù!
# Ran Gemma 3n through a quick ‚Äúbloatedness‚Äù visualisation, you can see on the graph how much code is scaffolding, even for a super clean & recent release.
#
# We are already tackling this at ü§ó : ùöùùöõùöäùöóùöúùöèùöòùöõùöñùöéùöõùöú and dubbed it ‚ÄúThe great unbloating‚Äù. The core PRs merged for this, among other things, move generic utils out of modeling files, updated linting, and overall prep a much, much slimmer v5.
#
# Ideally I'd like to divide by 10 the loc count of VLM modeling files üëÄ while keeping the hackability of the library's initial design. I'm getting started with the very popular InternVL and Gemma3n.
#  WDYT? What's your biggest pain point for VLM design/usage right now?
# 266
# 18 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face ü§ó
# 3d
# Edited
# Report this post
# We present `flux-fast`, a hackable repository of recipes to speed up Flux (Dev, Schnell, and Kontext) by upto ~2.5x üî•
#
# While we primarily targeted H100s, thanks to the community, the repository now also supports AMD cards üéõÔ∏è
#
# Our motivation was to introduce minimal and simple changes and test their effectiveness as a function of inference speed. Here's an overview of what we did:
#
# üëâ Making sure the models being compiled are set up for success through `torch.compile()`. We do this by ensuring the models don't have any graph-breaks, recompilation triggers, etc.
# üëâ Flash Attention v3 (FA3) with (unscaled) conversion of inputs to¬†torch.float8_e4m3fn.
# üëâ Dynamic FP8 through TorchAO.
# üëâ Eliminating the device-to-host syncs from the inference pipelines.
#
# We also show you how to enable CUDAGraphs when using `
# torch.export
# ` so that kernel launches aren't delayed.
#
# There are obviously other pieces of stuff that one could optimize:
#
# üß† Cache embeddings that don't change during denoising (`guidance_embedding`, `context_embedding`).
# üß† Fusing scheduler `step()` with DiT forward to avail more compilation benefits.
#
# It was fun collaborating with
# Joel Schlosser
# on this project. We invite you to check out the codebase, hack into it, and apply the recipes to your favorite pipeline:
# https://lnkd.in/gjV4YXMu
# 160
# 6 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Vaibhav Srivastav
# whatever needs doing @ Hugging Face
# 3d
# Report this post
# Yo yo! We're organising a small event to bring together the brightest minds in Paris next week! ü§ó
#
# Sign up here:
# https://lu.ma/ft1jex37
# Psyched to put this together with¬†
# SambaNova Systems
# , >Commit and
# The Linux Foundation
# ‚ö°
#
# Join us for an evening of fun conversations and good food! üí•
# 31
# 1 Comment
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning @ ü§ó Hugging Face
# 3d
# Report this post
# The Hugging Face hub is shaping up to be the ultimate MCP gateway. This is what it now adds to your AI assistant:
#
# + generative and utility tools via spaces like image generation
# + hub search for models, datasets, and spaces
# + docs search so your AI can understand all Hugging Face libraries
#
# Just plug in Claude Desktop, Cursor, or VSCode into the hub!
# 278
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at ü§ó
# 5d
# Report this post
# so many multimodal releases these days ü§†
# > ERNIE-4.5-VL: new vision language MoE models by Baidu
# > llama-nemoretriever-colembed: new visual document retrievers by NVIDIA (sota on ViDoRe!)
# > Ovis-3b: new image-text in image-text out models by Alibaba ‚§µÔ∏è
# find them in comments üí¨
# 226
# 7 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Julien Chaumond
# CTO at Hugging Face
# 3d
# Report this post
# I have bittersweet news to share. üò¢
#
# We are closing down huggingchat for now.
#
# Huggingchat was launched in April 2023 when ChatGPT was just 5 months old and it was still quite hard to deploy a similar service. The goal of this app was to showcase that it was now possible to build an open source alternative to ChatGPT, building on top of the community's models and building blocks. üí™
#
# We also built Huggingchat as a testbed to optimize inference which led to the creation of text-generation-inference, which in turn led to HF contributions to SGLang, vLLM,
# llama.cpp
# , and other LLM runtime engines since then.
#
# In the past 27 months we've launched:
# - üßô Assistants, an easy way to bundle a prompt, a model, and some tools into an easily-shareable URL you can send your friends
# - üõ†Ô∏è HuggingChat Tools, exposing the full ecosystem of
# Gradio
# Spaces straight from within the chat interface
# - üí¨ Many model launches were supported on HuggingChat: from OpenAssistant and all the LLamas, Phi-4, to Qwen, DeepSeek, Gemma.... üî•
#
# The app has always been free and experimental. We are closing it to make room for something new and more integrated with the HF ecosystem. You can export your past conversations as a zip file to load them into another interface.
#
# üí° If you are looking for a cool alternative interface you should take a look at:
# -
# LibreChat
# from
# Danny Avila
# and team: a clean and simple yet feature-packed chat interface
# -
# Open WebUI
# ‚Äì
# Tim Jaeryang Baek
# ‚Äì does it even need an intro anymore?
# - Scira MCP, an up and coming MCP-centric chat interface from Zaid Mukaddam
#
# üíü
# 1,762
# 61 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Freddy Boulton
# Software Engineer @ ü§ó
# 3d
# Report this post
# Help us revolutionize MCP development üöÄ
#
# We want
# Gradio
# to be the easiest and best way to build and deploy MCP servers. Your input is critical!
#
# New to Gradio for MCP? We'd love for you to try building a server and tell us what you think!
#
# Already tried it? Please share what's working well and what could be improved.
#
# üîó Get Started/Learn More:
# https://lnkd.in/ezzka4df
# üí≠ Share Feedback Here (or on GitHub):
# https://lnkd.in/ejpc4c-T
# Building Mcp Server With Gradio
# gradio.app
# 75
# 7 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Google DeepMind
# Research Services
# London, London
# Cohere
# Software Development
# Toronto, Ontario
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# ÿßŸÑÿπÿ±ÿ®Ÿäÿ© (Arabic)
# ‡¶¨‡¶æ‡¶Ç‡¶≤‡¶æ (Bangla)
# ƒåe≈°tina (Czech)
# Dansk (Danish)
# Deutsch (German)
# ŒïŒªŒªŒ∑ŒΩŒπŒ∫Œ¨ (Greek)
# English (English)
# Espa√±ol (Spanish)
# ŸÅÿßÿ±ÿ≥€å (Persian)
# Suomi (Finnish)
# Fran√ßais (French)
# ‡§π‡§ø‡§Ç‡§¶‡•Ä (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# ◊¢◊ë◊®◊ô◊™ (Hebrew)
# Êó•Êú¨Ë™û (Japanese)
# ÌïúÍµ≠Ïñ¥ (Korean)
# ‡§Æ‡§∞‡§æ‡§†‡•Ä (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ‡®™‡©∞‡®ú‡®æ‡®¨‡©Ä (Punjabi)
# Polski (Polish)
# Portugu√™s (Portuguese)
# Rom√¢nƒÉ (Romanian)
# –†—É—Å—Å–∫–∏–π (Russian)
# Svenska (Swedish)
# ‡∞§‡±Ü‡∞≤‡±Å‡∞ó‡±Å (Telugu)
# ‡∏†‡∏≤‡∏©‡∏≤‡πÑ‡∏ó‡∏¢ (Thai)
# Tagalog (Tagalog)
# T√ºrk√ße (Turkish)
# –£–∫—Ä–∞—ó–Ω—Å—å–∫–∞ (Ukrainian)
# Ti·∫øng Vi·ªát (Vietnamese)
# ÁÆÄ‰Ωì‰∏≠Êñá (Chinese (Simplified))
# Ê≠£È´î‰∏≠Êñá (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn‚Äôs
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn‚Äôs
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn‚Äôs
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don‚Äôt have the app? Get it in the Microsoft Store.
# Open the app

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nCommunity\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nblack-forest-labs/FLUX.1-Kontext-dev\nUpdated\n8 days ago\n•\n155k\n•\n1.32k\ntencent/Hunyuan-A13B-Instruct\nUpdated\n3 days ago\n•\n13.7k\n•\n709\ngoogle/gemma-3n-E4B-it\nUpdated\n2 days ago\n•\n197k\n•\n445\nTHUDM/GLM-4.1V-9B-Thinking\nUpdated\n2 days ago\n•\n7.03k\n•\n204\nkyutai/tts-1.6b-en_fr\nUpdated\n2 days ago\n•\n7.19k\n•\n164\nBrowse 1M+ models\nSpaces\nRunning\n9.25k\n9.25k\nDeepSite v2\n🐳\nGenerate any application with DeepSeek\nRunning\non\nZero\nMCP\n556\n556\nFLUX.1 Kontext\n⚡\nKontext image editing on FLUX[dev]\nRunning\n1.04k\n1.04k\nSparc3D\n🏃\nNext-Gen High-Resolution 3D Model Generation\nRunning\non\nZero\n124\n124\nOvis U1 3B\n🎨\nDemo for multimodal understanding and generation\nRunning\non\nZero\n622\n622\nHunyuan3D-2.1\n👻\nImage-to-3D Generation\nBrowse 400k+ applications\nDatasets\nfka/awesome-chatgpt-prompts\nUpdated\nJan 6\n•\n22.9k\n•\n8.15k\nHuggingFaceFW/fineweb-2\nUpdated\n8 days ago\n•\n38.3k\n•\n561\nfacebook/seamless-interaction\nUpdated\n8 days ago\n•\n1\n•\n80\nFreedomIntelligence/ShareGPT-4o-Image\nUpdated\n4 days ago\n•\n75\n•\n68\nblack-forest-labs/kontext-bench\nUpdated\n9 days ago\n•\n34\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nTeam & Enterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n766 models\n•\n3.52k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.17k models\n•\n6.7k followers\nAmazon\ncompany\n•\n20 models\n•\n3.27k followers\nGoogle\nEnterprise\ncompany\n•\n1.01k models\n•\n18.7k followers\nIntel\ncompany\n•\n207 models\n•\n2.7k followers\nMicrosoft\ncompany\n•\n396 models\n•\n13.3k followers\nGrammarly\nTeam\ncompany\n•\n10 models\n•\n166 followers\nWriter\nEnterprise\ncompany\n•\n21 models\n•\n309 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n146,474\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n29,647\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,340\nSafe way to store/distribute neural network weights\nHub Python Library\n2,735\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,868\nFast tokenizers optimized for research & production\nTRL\n14,454\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,986\nState-of-the-art ML running directly in your browser\nsmolagents\n20,925\nSmol library to build great agents in Python\nPEFT\n18,942\nParameter-efficient finetuning for large language models\nDatasets\n20,338\nAccess & share datasets for any ML tasks\ ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/about'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'contact page', 'url': 'https://huggingface.co/contact'}, {'type': 'community page', 'url': 'https://huggingface.co/discuss'}, {'type': 'social media page', 'url': 'https://twitter.com/huggingface'}, {'type': 'social media page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# ```markdown
# # Welcome to Hugging Face
#
# **The AI community building the future.**
#
# At Hugging Face, we are dedicated to creating a vibrant platform where the machine learning community can collaborate, innovate, and excel. With resources that empower users to create, discover, and share machine learning models, datasets, and applications, Hugging Face is at the forefront of AI technology.
#
# ---
#
# ## Our Offerings
#
# - **Models**: Browse and contribute to over **1 million+ models**.
# - **Datasets**: Access and share **250,000+ datasets** for all your machine learning needs.
# - **Spaces**: Deploy applications and tools seamlessly, hosting over **400,000 applications**.
#
# ### Key Features
# - **Open Source**: We build our tools with the community, fostering collaborative growth in ML.
# - **Enterprise Solutions**: Tailored paid services start at $20/user/month to help organizations scale their AI offerings with security and support.
# - **Compute Resources**: Accelerate your ML projects with our optimized inference endpoints, starting at $0.60/hour for GPU usage.
#
# ---
#
# ## Community and Collaboration
#
# Hugging Face is not just a platform; it's a thriving community of over **50,000 organizations** globally, including tech giants like **Google**, **Microsoft**, and **Amazon**, all utilizing our models and datasets for cutting-edge AI development.
#
# We prioritize collaboration and encourage users to build **ML portfolios**, share their work, and contribute to the open-source ecosystem.
#
# ---
#
# ## Company Culture
#
# At Hugging Face, we believe in the power of collaboration, innovation, and diversity. Our culture is rooted in openness and inclusivity, creating an environment where all voices are heard and valued. We focus on continuous learning, pushing the boundaries of AI technologies, and supporting our community in their growth journeys.
#
# ---
#
# ## Careers at Hugging Face
#
# Join a passionate and dynamic team that is shaping the future of AI! We are always looking for talented individuals dedicated to innovation and collaboration. Explore current openings on our [careers page](#) and be a part of our mission to democratize AI.
#
# ---
#
# ### Connect With Us
#
# - **Website**: [Hugging Face](https://huggingface.co)
# - **GitHub**: [Hugging Face on GitHub](https://github.com/huggingface)
# - **Twitter**: [@HuggingFace](https://twitter.com/huggingface)
# - **LinkedIn**: [Hugging Face on LinkedIn](https://linkedin.com/company/huggingface)
# - **Discord**: Join our vibrant community on Discord for discussions and support.
#
# ---
#
# Let’s build the future of AI, together.
# ```

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'docs page', 'url': 'https://huggingface.co/docs'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community discussion page', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Brochure
#
# ## Welcome to Hugging Face
# ### The AI Community Building the Future
#
# At Hugging Face, we believe in the transformative power of artificial intelligence and machine learning. Our platform serves as a collaborative space for developers, researchers, and enthusiasts to create, share, and enhance machine learning models and applications.
#
# ---
#
# ## Key Features
#
# - **Extensive Model Repository**: Access over 1 million models across various modalities, including text, images, video, audio, and 3D.
# - **Datasets**: Browse a vast collection of 250,000+ datasets to support your machine learning projects.
# - **Spaces**: Create and deploy applications effortlessly with our Spaces functionality, featuring tools like DeepSite v2 and more.
# - **Community Driven**: Join a thriving community of over 50,000 organizations, including leaders from Google, Microsoft, and Amazon.
#
# ---
#
# ## Company Culture
#
# We are committed to fostering a culture of inclusivity, collaboration, and innovation. Our community-driven approach encourages contributions from all backgrounds, ensuring that our tools and models are continuously improving. Hugging Face is not just a platform; it's a community dedicated to democratizing access to machine learning.
#
# - **Open Source Philosophy**: Our projects, including Transformers and Diffusers, are built and maintained with community input to create state-of-the-art ML tooling.
# - **Supportive Environment**: We prioritize knowledge sharing and provide extensive documentation, forums, and resources to help users navigate their machine learning journey.
#
# ---
#
# ## Customers
#
# Our diverse clientele ranges from small startups to large enterprises. We empower organizations to build innovative AI solutions with enterprise-grade security and support. Key customers include:
#
# - AI at Meta
# - Google
# - Microsoft
# - Amazon
# - Grammarly
#
# With over 50,000 organizations leveraging our platform, we are helping shape the future of machine learning.
#
# ---
#
# ## Careers at Hugging Face
#
# As we continue to grow, we are always on the lookout for passionate individuals to join our team. We offer various roles that invite creativity and support personal and professional development.
#
# - **Diverse Opportunities**: Roles in engineering, product management, community engagement, and more.
# - **Collaborative Environment**: Work with cutting-edge technology alongside experts in AI and machine learning.
# - **Competitive Benefits**: We offer comprehensive benefits packages, fostering work-life balance and professional growth.
#
# If you are excited about AI and want to make a meaningful impact, explore our job openings and become part of the Hugging Face community!
#
# ---
#
# ## Get Involved!
#
# Join us on our mission to democratize AI. Explore our resources, participate in community discussions, or contribute to our open-source projects. Together, we can build a brighter future through technology.
#
# ### Connect with Us
# - [Website](https://huggingface.co)
# - [GitHub](https://github.com/huggingface)
# - [Twitter](https://twitter.com/huggingface)
# - [LinkedIn](https://linkedin.com/company/hugging-face)
#
# ---
#
# Join Hugging Face and be a part of the AI revolution!

# %%
# A more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
 and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
 Include details of company culture, customers and careers/jobs if you have the information."

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}]}
# # Welcome to Hugging Face: The Huggable Future of AI!
#
# 🌟 **Where AI Goes for a Cuddle!** 🌟
#
# Hey there, aspiring AI-ologist! If you've ever found yourself daydreaming about a community where humans and AI snuggle together to build something beautiful and pioneering, then stop right there! You’re in the right place. Let us introduce you to **Hugging Face** – your new favorite AI family!
#
# ## 🤖 **What We Do**
#
# At Hugging Face, we believe that building the future can be a *team sport*! Our platform is the ultimate playground for the machine learning community. With collaboration on over **1 Million+ models** and **250k+ datasets**, we’re like the “Hugging Wonderland” for machine learning fanatics.
#
# ### Quick Highlights:
# - **Trending Models:**
#   - *FLUX.1-Kontext-dev:* Updated 8 days ago, 155k fans (every hug counts 🥰).
#   - *Hunyuan-A13B-Instruct:* Because sometimes, you need a smart bear to take direction (instructed with *love*, of course).
#
# - **Snap, Share & Hug:** Whether it’s text, image, audio, video, or even 3D fun—we’ve got it all!
#
# ## 🌈 **Company Culture: A Hug Above the Rest!**
#
# Here at Hugging Face, we significantly value **collaboration, creativity, and a generally chill vibe**. Our team is a colorful mosaic of talents and backgrounds – think of it as a techie talent show minus the awkwardness! We work together, learn from each other, and use humor to solve perplexing puzzles.
#
# ### ✈️ **Perks of Joining the Hug:**
# - Super friendly teammates who provide their best bear hugs (metaphorical, of course).
# - A space where everyone's ideas count, kind of like a brainstorming cuddle puddle!
# - Opportunities to work on meaningful, impactful projects that would make even your AI teddy bear proud.
#
# ## 👫 **Join the Hugging Family!**
#
# **Careers at Hugging Face** are not just about code and algorithms—you'll also get the chance to innovate, inspire, and incorporate your love of **AI goodness** into your work life! Current openings range from model wranglers to data explorers, and yes—AI whisperers!
#
# 🔍 **Have you got what it takes?**
# Check out our careers page: [Jobs at Hugging Face](#)
#
# ## 🚀 **Who Loves Us?**
#
# Over **50,000 organizations** can’t get enough of our warm embraces— from **AI2** to **Google**, to **Microsoft**! They all recognize the power of collaboration and creativity in the world of machine learning.
#
# ## 🏆 **Why Choose Hugging Face?**
#
# - Collaborate on **enterprise-grade solutions** with security snuggles.
# - **Affordable pricing!** Cloud resources as low as **$0.60/hour** (because who doesn’t love a bargain?).
# - **Community support** that really means “we’ve got your back!”
#
# So, whether you're a customer, investor, or simply someone looking to make their career dreams come true in AI, let’s transform the technological landscape together!
#
# Join us and help build a future where every hug brings innovation, creativity, and a whole lot of fun!
#
# ---
#
# ### 🤗 **Hugging Face: Wherever You Are, We’re Here for the Hugs!**
#
# Feel free to browse through our services, look at our endless models, or just drop us a line to say ‘hey’! Remember, we’re just a hug away!
#
# ---
#
# **Find us here:**
# - [Website](https://huggingface.co)
# - [Twitter](https://twitter.com/huggingface)
# - [Discord](https://discord.com/invite/huggingface)
#
# Hugs,
# **The Hugging Face Team**

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
